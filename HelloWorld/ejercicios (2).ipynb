# %% [markdown]
# # Examen final, convocatoria ordinaria curso 2023-24 (23 de mayo)
#
# ## Modifica esta plantilla para dar tus soluciones para los ejercicios 1 y 2 del examen
#
# ### Recursos externos
#
# Recuerda que:
#
# - **puedes** hacer uso de material subido por tí o por el profesor a Campus Virtual, que es también donde entregarás el examen
#
# - **puedes** buscar cualquier duda en google ó similar, y hacer uso de cualquier recurso que existiese en el momento de comenzar el examen. Por ejemplo, puedes acceder preguntas y respuestas (previas al comienzo del examen) en [StackOverflow](https://stackoverflow.com), o a la documentación de
#     + [Python](https://docs.python.org/3/)
#     + [Pandas](https://pandas.pydata.org/docs/index.html)
#     + [MatPlotLib](https://matplotlib.org/stable/index.html)
#     + [Plotly](https://plotly.com/python/)
#
# - **no puedes** colaborar con compañeros ó terceros (ó herramientas tipo ChatGPT), ni solicitar ni proporcionar ayuda a nada ni nadie, exceptuando el profesor, que podrá ayudarte con problemas de claridad del enunciado o de configuración del entorno.
#
# ### Uso de plantilla
#
# Para facilitar al profesor las correcciones, por favor, **usa la carga de datos de la plantilla**. Eso agilizará las correcciones.
#
# **Puedes (y debes) crear celdas adicionales que necesites. Por favor, no modifiques o elimines las existentes.**
#
# Puedes incluir cualquier librería que estimes oportuno para realizar los ejercicios (y que consigas instalar en el entorno), dentro de lo que hemos venido usando durante el curso. **Documenta el uso de librerías no-estándar** con comentarios allí donde sea apropiado incluirla(s).

# %%
import pandas as pd
import numpy as np

# atletas en JJOO Tokyo 2020
#   gender = Female, Male
#   country = país == country_code = país (3 letras)
#   discipline = deporte
#   height_m/ft = altura en m/pies - usa sólo m, por favor
athletes = pd.read_csv("athletes.csv", delimiter=",")
athletes['height_m/ft'] = athletes['height_m/ft'].fillna(0)

# entrenadores
#   gender = Female, Male
#   country_code = país (3 letras)
#   discipline = deporte
coaches = pd.read_csv("coaches.csv", delimiter=",")

# medallas
#   medal_type = Gold Medal, Silver Medal, Bronze Medal == medal_code = 1, 2, 3
#   country = país == country_code = país (3 letras)
#   discipline = deporte
medals = pd.read_csv("medals.csv", delimiter=",")

# %%
athletes.head(7)
# Out:
#                 name  short_name  gender  birth_date     birth_place  \
# 0    AALERUD Katrine   AALERUD K  Female  1994-12-04          VESTBY
# 1        ABAD Nestor      ABAD N    Male  1993-03-29           ALCOI
# 2  ABAGNALE Giovanni  ABAGNALE G    Male  1995-01-11        GRAGNANO
# 3     ABALDE Alberto    ABALDE A    Male  1995-12-15          FERROL
# 4      ABALDE Tamara    ABALDE T  Female  1989-02-06            VIGO
# 5          ABALO Luc     ABALO L    Male  1984-09-06  IVRY-SUR-SEINE
# 6       ABAROA Cesar    ABAROA C    Male  1996-11-18      CONCEPCION
#
#   birth_country country country_code           discipline discipline_code  \
# 0        Norway  Norway          NOR         Cycling Road             CRD
# 1         Spain   Spain          ESP  Artistic Gymnastics             GAR
# 2         Italy   Italy          ITA               Rowing             ROW
# 3         Spain   Spain          ESP           Basketball             BKB
# ...

# %%
coaches.head(7)
# Out:
#                         name    short_name gender  birth_date country_code  \
# 0            ABDELMAGID Wael  ABDELMAGID W   Male  1982-08-02          EGY
# 1                  ABE Junya         ABE J   Male  1990-07-25          JPN
# 2              ABE Katsuhiko         ABE K   Male  1979-09-23          JPN
# 3               ADAMA Cherif       ADAMA C   Male  1962-05-06          CIV
# 4                 AGEBA Yuya       AGEBA Y   Male  1983-09-30          JPN
# 5  AIKMAN Siegfried Gottlieb     AIKMAN SG   Male  1959-04-28          JPN
# 6              AL SAADI Kais    AL SAADI K   Male  1976-11-06          GER
#
#    discipline    function event  \
# 0    Football  Head Coach   NaN
# 1  Volleyball  Head Coach   NaN
# 2  Basketball       Coach   NaN
# 3    Football  Head Coach   NaN
# 4  Volleyball  Head Coach   NaN
# 5      Hockey  Head Coach   Men
# 6      Hockey  Head Coach   Men
#
#                                                  url
# ...

# %%
medals.head(7)
# Out:
#      medal_type  medal_code             medal_date athlete_short_name  \
# 0    Gold Medal           1  2021-07-24 00:00:00.0             KIM JD
# 1    Gold Medal           1  2021-07-24 00:00:00.0               AN S
# 2  Silver Medal           2  2021-07-24 00:00:00.0       SCHLOESSER G
# 3  Silver Medal           2  2021-07-24 00:00:00.0           WIJLER S
# 4  Bronze Medal           3  2021-07-24 00:00:00.0          ALVAREZ L
# 5  Bronze Medal           3  2021-07-24 00:00:00.0         VALENCIA A
# 6    Gold Medal           1  2021-07-24 00:00:00.0          CARAPAZ R
#
#           athlete_name athlete_sex  \
# 0          KIM Je Deok           X
# 1               AN San           X
# 2  SCHLOESSER Gabriela           X
# 3         WIJLER Steve           X
# 4         ALVAREZ Luis           X
# 5   VALENCIA Alejandra           X
# 6      CARAPAZ Richard           M
#
#                                         athlete_link country_code  \
# ...

# %% [markdown]
# ## Ejercicio 1 (2.5 puntos): vistazo general
#
# En este primer ejercicio se te pide mostrar a grandes rasgos qué hay en el conjunto de datos. Para ello, debes generar visualizaciones, lo más autoexplicativas posibles, que contesten las  preguntas 1.a y 1.b; posteriormente, contesta (sin visualizaciones, sólo con texto) a 1.c:
#
# ### 1.a (1 pto): ¿De dónde son los atletas que asisten?

# %%
countries = athletes.country_code.value_counts()
countries

countries.plot(kind="bar")
# Out:
# <Axes: xlabel='country_code'>

# %%
countries = countries[countries>100]

countries.plot(kind="bar")
# Out:
# <Axes: xlabel='country_code'>

# %% [markdown]
# ### 1.b (1 pto): ¿Qué países consiguen más medallas?

# %%
medal = medals.groupby("country_code")["medal_code"].count().nlargest(10)
medal.plot(kind="bar")
# Out:
# <Axes: xlabel='country_code'>

# %% [markdown]
# ### 1.c (0.5 ptos): Posibles mejoras
#
# Explica de forma breve (sólo con texto) qué otras visualizaciones podrías generar para proporcionar un vistazo general a los datos; y cómo podrías, con más tiempo, mejorar tus visualizaciones de los apartados 1.a y 1.b

# %% [markdown]
# ## Ejercicio 2 (3.5 puntos): preguntas enfocadas
#
# En este ejercicio debes mostrar visualizaciones que contestan preguntas más enfocadas (2.a y 2.b), y además, debes añadir texto argumentando una respuesta. El texto no tiene que ser largo, pero sí debe indicar una respuesta, y dónde en tu visualización se puede ver que ésa es una buena respuesta. Posteriormente, contesta (sin visualizaciones, sólo con texto) a 3.c:
#
# ### 2.a (1.5 ptos): ¿En qué deportes es mejor y peor ser alto?

# %%
data = athletes[["discipline_code", "height_m/ft"]][athletes["height_m/ft"] != 0]

for ath in data:
  #coger 3 primeros (cm)

#agrupar en alturas/deporte y ver max y min
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-54ffebcde85f> in <cell line: 2>()
#       1 data = athletes[["discipline_code", "height_m/ft"]][athletes["height_m/ft"] != 0]
# ----> 2 data = data[data["height_m/ft"][0:3]]
#       3 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
# ...

# %% [markdown]
# ### 2.b (1.5 ptos): ¿Qué países envían representaciones (en deportistas y entrenadores) más y menos equilibradas en género a los JJOO? Ignora países que enviaron menos de 50 deportistas en total.

# %% [markdown]
# ### 2.c (0.5 ptos): Posibles mejoras
#
# Explica de forma breve (sólo con texto) qué otras visualizaciones podrías generar para contestar mejor a las preguntas anteriores; y cómo podrías, con más tiempo, mejorar tus visualizaciones de los apartados 2.a y 2.b

# %% [markdown]
# ## Ejercicio 3 (4 puntos): dashboard
#
# Genera un dashboard que permita explorar *equilibrio de género* en los *deportistas* que los países enviaron a estas olimpiadas, y compararlo con las *medallas obtenidas* por estos paises.
#
# Debe ser posible filtrar por número de deportistas enviados por el país, de forma que se excluyan países que contribuyeron menos de X deportistas. Puedes añadir filtros adicionales a tu discreción.
#
# Debes intentar que los tooltips sean lo más informativos posible, para facilitar comparaciones.

# %%
# Nota: es OPCIONAL realizar este ejercicio aquí -- también lo puedes sacar todo a un app.py externo
# No modifiques otras celdas, pero MODIFICA ESTA CELDA COMO VEAS OPORTUNO

from dash import Dash, html, dash_table, dcc, callback, Output, Input
import plotly.subplots as subplots

# Inicialización de la aplicación
app = Dash(__name__)

# Colocación de elementos
app.layout = html.Div([
    html.H1(children='Género y medallas en los JJOO'),
    html.Hr(),
    html.Div(['Reemplázame por visualizaciones, controles y texto descriptivo'])
])

# Aquí tus @callback y funciones asociadas

# Para uso en un .py independiente
if __name__ == '__main__':
    app.run(debug=True)
# Out:
# Address already in use
# Port 8050 is in use by another program. Either identify and stop that program, or start the server with a different port.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/werkzeug/serving.py:746, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     745 try:
# --> 746     self.server_bind()
#     747     self.server_activate()
#
# File /usr/lib/python3.10/http/server.py:137, in HTTPServer.server_bind(self)
#     136 """Override server_bind to store the server name."""
# --> 137 socketserver.TCPServer.server_bind(self)
#     138 host, port = self.server_address[:2]
#
# File /usr/lib/python3.10/socketserver.py:466, in TCPServer.server_bind(self)
#     465     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
# ...
